# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATA_PATH = '/content/gdrive/MyDrive/Colab Notebooks/data2.json' # path of the file which has the processed data stored in JSON format

def load_data(data_path):
    '''
    function to load data from the JSON file
    param: data_path -> string -> the path of the JSON file which will be used to load data
    return: X -> ndarray -> the extracted input features from the loaded file
            Y -> ndarray -> the expected output for the corresponding inputs in X
    '''
    
    with open(data_path, 'r') as fp:
        data = json.load(fp)
    
    # converting list to ndarrays
    X = np.array(data['mfcc'])
    Y = np.array(data['labels'])
    print('Data Loaded Successfully!')
    
    return X, Y

X, Y = load_data(DATA_PATH) # loading data to X and Y

def plot_history(history):
    # function to plot the history of the training of the model
    
    fig, axs = plt.subplots(2)
    
    # plotting accuracy history of training and validation datasets
    axs[0].plot(history.history["accuracy"], label = 'train-accuracy')
    axs[0].plot(history.history["val_accuracy"], label = 'validation-accuracy')
    axs[0].set_ylabel('accuracy')
    axs[0].set_xlabel('epochs')
    axs[0].legend(loc = 'lower right')
    axs[0].set_title('Accuracy Evaluation')
    
    # plotting error history of training and validation datasets
    axs[1].plot(history.history["loss"], label = 'training-loss')
    axs[1].plot(history.history["val_loss"], label = 'validation-loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].legend('upper right')
    axs[1].set_title('Loss Evaluation')
    
    plt.show()
    
def prepare_dataset(validation_size, test_size):
    # function to split the dataset into traning, validation and test sets
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_size)
    X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = validation_size)
    return X_train, X_val, X_test, Y_train, Y_val, Y_test
# Out:
# Data Loaded Successfully!

# %%
def build_model(input_shape):
    # building a RNN-LSTM model
    model = keras.Sequential()
    
    # adding LSTM layers
    model.add(keras.layers.LSTM(60, input_shape = input_shape, return_sequences = True))
    model.add(keras.layers.LSTM(60))
    
    # dense neural network layer
    model.add(keras.layers.Dense(64, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dense(128, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dense(64, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3))
    model.add(keras.layers.BatchNormalization())
    # final softmax layer 
    model.add(keras.layers.Dense(10, activation = 'softmax'))

    return model

if(__name__ == '__main__'):
    X_train, X_val, X_test, Y_train, Y_val, Y_test = prepare_dataset(0.25, 0.20)
    
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_model(input_shape)
    
    optimizer = keras.optimizers.Adam(learning_rate = 0.001)
    
    model.compile(optimizer = optimizer,
                 loss = 'sparse_categorical_crossentropy',
                 metrics = ['accuracy'])
    
    model.summary()
    
    history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size = 32, epochs = 100)
    
    plot_history(history)
    
    test_loss, test_acc = model.evaluate(X_test, Y_test, verbose = 2)
    
    print(f'Test Accuracy: {test_acc}')
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 130, 60)           20160
#
#  lstm_21 (LSTM)              (None, 60)                29040
#
#  dense_34 (Dense)            (None, 64)                3904
#
#  dropout_24 (Dropout)        (None, 64)                0
#
#  batch_normalization_24 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_35 (Dense)            (None, 128)               8320
#
#  dropout_25 (Dropout)        (None, 128)               0
#
#  batch_normalization_25 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_36 (Dense)            (None, 64)                8256
#
#  dropout_26 (Dropout)        (None, 64)                0
#
#  batch_normalization_26 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_37 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 71,354
# Trainable params: 70,842
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/100
# 188/188 [==============================] - 7s 20ms/step - loss: 2.3196 - accuracy: 0.2310 - val_loss: 1.8788 - val_accuracy: 0.3741
# Epoch 2/100
# 188/188 [==============================] - 3s 16ms/step - loss: 1.8779 - accuracy: 0.3393 - val_loss: 1.5336 - val_accuracy: 0.4472
# Epoch 3/100
# 188/188 [==============================] - 3s 16ms/step - loss: 1.6718 - accuracy: 0.3999 - val_loss: 1.4541 - val_accuracy: 0.5013
# Epoch 4/100
# 188/188 [==============================] - 3s 16ms/step - loss: 1.5353 - accuracy: 0.4525 - val_loss: 1.3957 - val_accuracy: 0.4907
# Epoch 5/100
# 188/188 [==============================] - 3s 16ms/step - loss: 1.4608 - accuracy: 0.4777 - val_loss: 1.3729 - val_accuracy: 0.4917
# Epoch 6/100
# 188/188 [==============================] - 3s 16ms/step - loss: 1.4078 - accuracy: 0.4957 - val_loss: 1.3312 - val_accuracy: 0.5378
# Epoch 7/100
# 188/188 [==============================] - 3s 15ms/step - loss: 1.3738 - accuracy: 0.5029 - val_loss: 1.3334 - val_accuracy: 0.5113
# Epoch 8/100
# 188/188 [==============================] - 3s 15ms/step - loss: 1.3023 - accuracy: 0.5411 - val_loss: 1.2326 - val_accuracy: 0.5548
# Epoch 9/100
# 188/188 [==============================] - 3s 15ms/step - loss: 1.2324 - accuracy: 0.5707 - val_loss: 1.2503 - val_accuracy: 0.5684
# Epoch 10/100
# 188/188 [==============================] - 3s 16ms/step - loss: 1.2048 - accuracy: 0.5780 - val_loss: 1.1288 - val_accuracy: 0.6034
# Epoch 11/100
# 188/188 [==============================] - 3s 16ms/step - loss: 1.1324 - accuracy: 0.6051 - val_loss: 1.1230 - val_accuracy: 0.6004
# Epoch 12/100
# 188/188 [==============================] - 3s 16ms/step - loss: 1.0933 - accuracy: 0.6281 - val_loss: 1.0024 - val_accuracy: 0.6610
# Epoch 13/100
# 188/188 [==============================] - 4s 20ms/step - loss: 1.0262 - accuracy: 0.6572 - val_loss: 1.0044 - val_accuracy: 0.6680
# Epoch 14/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.9840 - accuracy: 0.6720 - val_loss: 0.9508 - val_accuracy: 0.6825
# Epoch 15/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.9499 - accuracy: 0.6844 - val_loss: 1.1576 - val_accuracy: 0.6259
# Epoch 16/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.8997 - accuracy: 0.7094 - val_loss: 0.9119 - val_accuracy: 0.7086
# Epoch 17/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.8817 - accuracy: 0.7102 - val_loss: 0.8946 - val_accuracy: 0.7176
# Epoch 18/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.8444 - accuracy: 0.7261 - val_loss: 1.0009 - val_accuracy: 0.6775
# Epoch 19/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.8136 - accuracy: 0.7363 - val_loss: 0.8472 - val_accuracy: 0.7346
# Epoch 20/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.7649 - accuracy: 0.7515 - val_loss: 0.9077 - val_accuracy: 0.6965
# Epoch 21/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.7737 - accuracy: 0.7483 - val_loss: 0.8086 - val_accuracy: 0.7416
# Epoch 22/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.6931 - accuracy: 0.7803 - val_loss: 0.8366 - val_accuracy: 0.7426
# Epoch 23/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.6828 - accuracy: 0.7790 - val_loss: 0.7884 - val_accuracy: 0.7566
# Epoch 24/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.6754 - accuracy: 0.7853 - val_loss: 0.8283 - val_accuracy: 0.7466
# Epoch 25/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.6602 - accuracy: 0.7885 - val_loss: 0.8400 - val_accuracy: 0.7361
# Epoch 26/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.6821 - accuracy: 0.7740 - val_loss: 0.8115 - val_accuracy: 0.7531
# Epoch 27/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.6287 - accuracy: 0.8027 - val_loss: 0.8469 - val_accuracy: 0.7396
# Epoch 28/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.5874 - accuracy: 0.8147 - val_loss: 0.8217 - val_accuracy: 0.7481
# Epoch 29/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.5846 - accuracy: 0.8196 - val_loss: 0.8019 - val_accuracy: 0.7611
# Epoch 30/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.5607 - accuracy: 0.8197 - val_loss: 0.7525 - val_accuracy: 0.7772
# Epoch 31/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.5335 - accuracy: 0.8341 - val_loss: 0.8237 - val_accuracy: 0.7606
# Epoch 32/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.5175 - accuracy: 0.8404 - val_loss: 0.8123 - val_accuracy: 0.7712
# Epoch 33/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.4879 - accuracy: 0.8463 - val_loss: 0.7666 - val_accuracy: 0.7822
# Epoch 34/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.4960 - accuracy: 0.8459 - val_loss: 0.9132 - val_accuracy: 0.7416
# Epoch 35/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.4819 - accuracy: 0.8524 - val_loss: 0.7858 - val_accuracy: 0.7837
# Epoch 36/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.5144 - accuracy: 0.8403 - val_loss: 0.8089 - val_accuracy: 0.7692
# Epoch 37/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.4584 - accuracy: 0.8626 - val_loss: 0.7259 - val_accuracy: 0.7952
# Epoch 38/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.4505 - accuracy: 0.8650 - val_loss: 0.8383 - val_accuracy: 0.7651
# Epoch 39/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.4102 - accuracy: 0.8748 - val_loss: 0.8004 - val_accuracy: 0.7922
# Epoch 40/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.4347 - accuracy: 0.8696 - val_loss: 0.7859 - val_accuracy: 0.7712
# Epoch 41/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.4283 - accuracy: 0.8680 - val_loss: 0.8048 - val_accuracy: 0.7687
# Epoch 42/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.3975 - accuracy: 0.8800 - val_loss: 0.7844 - val_accuracy: 0.7757
# Epoch 43/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.4136 - accuracy: 0.8735 - val_loss: 0.7690 - val_accuracy: 0.7927
# Epoch 44/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.4028 - accuracy: 0.8833 - val_loss: 0.8868 - val_accuracy: 0.7516
# Epoch 45/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.3925 - accuracy: 0.8812 - val_loss: 0.7795 - val_accuracy: 0.7812
# Epoch 46/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.3545 - accuracy: 0.8937 - val_loss: 0.7190 - val_accuracy: 0.8027
# Epoch 47/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.3453 - accuracy: 0.8975 - val_loss: 0.7657 - val_accuracy: 0.7922
# Epoch 48/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.3658 - accuracy: 0.8897 - val_loss: 0.8133 - val_accuracy: 0.7782
# Epoch 49/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.3785 - accuracy: 0.8862 - val_loss: 0.7748 - val_accuracy: 0.7867
# Epoch 50/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.3472 - accuracy: 0.9015 - val_loss: 0.7875 - val_accuracy: 0.7927
# Epoch 51/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.3458 - accuracy: 0.8942 - val_loss: 0.9761 - val_accuracy: 0.7536
# Epoch 52/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.3465 - accuracy: 0.8963 - val_loss: 0.7629 - val_accuracy: 0.7917
# Epoch 53/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.2801 - accuracy: 0.9169 - val_loss: 0.7680 - val_accuracy: 0.8032
# Epoch 54/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2899 - accuracy: 0.9117 - val_loss: 0.7440 - val_accuracy: 0.8072
# Epoch 55/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2946 - accuracy: 0.9167 - val_loss: 0.7541 - val_accuracy: 0.8112
# Epoch 56/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.2862 - accuracy: 0.9172 - val_loss: 0.9240 - val_accuracy: 0.7797
# Epoch 57/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.3250 - accuracy: 0.9072 - val_loss: 0.8051 - val_accuracy: 0.7847
# Epoch 58/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2636 - accuracy: 0.9234 - val_loss: 0.8549 - val_accuracy: 0.8057
# Epoch 59/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2726 - accuracy: 0.9209 - val_loss: 0.7770 - val_accuracy: 0.8117
# Epoch 60/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2607 - accuracy: 0.9236 - val_loss: 0.7760 - val_accuracy: 0.8087
# Epoch 61/100
# 188/188 [==============================] - 4s 21ms/step - loss: 0.2647 - accuracy: 0.9209 - val_loss: 0.8225 - val_accuracy: 0.8017
# Epoch 62/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.4239 - accuracy: 0.8780 - val_loss: 0.7524 - val_accuracy: 0.8127
# Epoch 63/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2442 - accuracy: 0.9306 - val_loss: 0.8738 - val_accuracy: 0.7942
# Epoch 64/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2561 - accuracy: 0.9311 - val_loss: 0.8484 - val_accuracy: 0.8032
# Epoch 65/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.2589 - accuracy: 0.9254 - val_loss: 0.7772 - val_accuracy: 0.8077
# Epoch 66/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.2182 - accuracy: 0.9379 - val_loss: 0.8442 - val_accuracy: 0.7907
# Epoch 67/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2153 - accuracy: 0.9394 - val_loss: 0.8455 - val_accuracy: 0.8077
# Epoch 68/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.2107 - accuracy: 0.9389 - val_loss: 0.8309 - val_accuracy: 0.8132
# Epoch 69/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2162 - accuracy: 0.9351 - val_loss: 0.8597 - val_accuracy: 0.7997
# Epoch 70/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2426 - accuracy: 0.9301 - val_loss: 0.8112 - val_accuracy: 0.8117
# Epoch 71/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2142 - accuracy: 0.9401 - val_loss: 0.9170 - val_accuracy: 0.7927
# Epoch 72/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2062 - accuracy: 0.9426 - val_loss: 0.8127 - val_accuracy: 0.8107
# Epoch 73/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.1857 - accuracy: 0.9478 - val_loss: 0.8901 - val_accuracy: 0.8032
# Epoch 74/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.1824 - accuracy: 0.9484 - val_loss: 0.9810 - val_accuracy: 0.8007
# Epoch 75/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1887 - accuracy: 0.9481 - val_loss: 0.9310 - val_accuracy: 0.7947
# Epoch 76/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2037 - accuracy: 0.9436 - val_loss: 0.8294 - val_accuracy: 0.8147
# Epoch 77/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1724 - accuracy: 0.9516 - val_loss: 0.9918 - val_accuracy: 0.7897
# Epoch 78/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1977 - accuracy: 0.9473 - val_loss: 0.8390 - val_accuracy: 0.8202
# Epoch 79/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1476 - accuracy: 0.9573 - val_loss: 0.9746 - val_accuracy: 0.8037
# Epoch 80/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2394 - accuracy: 0.9321 - val_loss: 0.9002 - val_accuracy: 0.7997
# Epoch 81/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1844 - accuracy: 0.9498 - val_loss: 0.8610 - val_accuracy: 0.8072
# Epoch 82/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1860 - accuracy: 0.9469 - val_loss: 0.8433 - val_accuracy: 0.8187
# Epoch 83/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1657 - accuracy: 0.9534 - val_loss: 0.8080 - val_accuracy: 0.8277
# Epoch 84/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2391 - accuracy: 0.9356 - val_loss: 0.8553 - val_accuracy: 0.7982
# Epoch 85/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1750 - accuracy: 0.9514 - val_loss: 0.8932 - val_accuracy: 0.8157
# Epoch 86/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1742 - accuracy: 0.9494 - val_loss: 0.8210 - val_accuracy: 0.8132
# Epoch 87/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.1315 - accuracy: 0.9638 - val_loss: 0.9699 - val_accuracy: 0.8032
# Epoch 88/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1647 - accuracy: 0.9611 - val_loss: 0.9607 - val_accuracy: 0.7982
# Epoch 89/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1628 - accuracy: 0.9571 - val_loss: 0.9296 - val_accuracy: 0.8122
# Epoch 90/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.1277 - accuracy: 0.9646 - val_loss: 0.9768 - val_accuracy: 0.8172
# Epoch 91/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1835 - accuracy: 0.9486 - val_loss: 0.9897 - val_accuracy: 0.8002
# Epoch 92/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1905 - accuracy: 0.9503 - val_loss: 0.9772 - val_accuracy: 0.8067
# Epoch 93/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1809 - accuracy: 0.9501 - val_loss: 0.8592 - val_accuracy: 0.8127
# Epoch 94/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1103 - accuracy: 0.9701 - val_loss: 1.0096 - val_accuracy: 0.8042
# Epoch 95/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1551 - accuracy: 0.9586 - val_loss: 0.9332 - val_accuracy: 0.8112
# Epoch 96/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.1712 - accuracy: 0.9518 - val_loss: 0.9183 - val_accuracy: 0.8042
# Epoch 97/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1628 - accuracy: 0.9569 - val_loss: 0.8298 - val_accuracy: 0.8057
# Epoch 98/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1324 - accuracy: 0.9636 - val_loss: 0.9806 - val_accuracy: 0.8042
# Epoch 99/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1292 - accuracy: 0.9643 - val_loss: 1.0555 - val_accuracy: 0.7927
# Epoch 100/100
# 188/188 [==============================] - 3s 16ms/step - loss: 0.1358 - accuracy: 0.9663 - val_loss: 0.9424 - val_accuracy: 0.8097
# 63/63 - 0s - loss: 0.8762 - accuracy: 0.8203 - 472ms/epoch - 7ms/step
# Test Accuracy: 0.8203203082084656
