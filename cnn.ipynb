# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATA_PATH = '/content/gdrive/MyDrive/Colab Notebooks/data2.json' # path of the file which has the processed data stored in JSON format

def load_data(data_path):
    '''
    function to load data from the JSON file
    param: data_path -> string -> the path of the JSON file which will be used to load data
    return: X -> ndarray -> the extracted input features from the loaded file
            Y -> ndarray -> the expected output for the corresponding inputs in X
    '''
    
    with open(data_path, 'r') as fp:
        data = json.load(fp)
    
    # converting list to ndarrays
    X = np.array(data['mfcc'])
    Y = np.array(data['labels'])
    print('Data Loaded Successfully!')
    
    return X, Y

X, Y = load_data(DATA_PATH) # loading data to X and Y

def plot_history(history):
    # function to plot the history of the training of the model
    
    fig, axs = plt.subplots(2)
    
    # plotting accuracy history of training and validation datasets
    axs[0].plot(history.history["accuracy"], label = 'train-accuracy')
    axs[0].plot(history.history["val_accuracy"], label = 'validation-accuracy')
    axs[0].set_ylabel('accuracy')
    axs[0].set_xlabel('epochs')
    axs[0].legend(loc = 'lower right')
    axs[0].set_title('Accuracy Evaluation')
    
    # plotting error history of training and validation datasets
    axs[1].plot(history.history["loss"], label = 'training-loss')
    axs[1].plot(history.history["val_loss"], label = 'validation-loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].legend('upper right')
    axs[1].set_title('Loss Evaluation')
    
    plt.show()
    
def prepare_dataset(validation_size, test_size):
    # function to split the dataset into traning, validation and test sets
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_size)
    X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = validation_size)
    X_train = X_train[..., np.newaxis]
    X_val = X_val[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    return X_train, X_val, X_test, Y_train, Y_val, Y_test
# Out:
# Data Loaded Successfully!

# %%
def build_model(input_shape):
    # building a Convolutional Neural Network
    model = keras.Sequential()
    
    #adding convolutional and pooling layers to the model
    model.add(keras.layers.Conv2D(30, (3, 3), activation = 'relu', input_shape = input_shape)) # convoluition layer
    model.add(keras.layers.MaxPooling2D((2, 2), strides = (2, 2), padding = 'same')) # pooling layer
    model.add(keras.layers.Dropout(0.1))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(60, (3, 3), activation = 'relu')) # convolution layer
    model.add(keras.layers.MaxPooling2D((3, 3), strides = (2, 2), padding = 'same')) # pooling layer
    model.add(keras.layers.Dropout(0.1))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(60, (2, 2), activation = 'relu')) # convolution layer
    model.add(keras.layers.MaxPooling2D((2, 2), strides = (2, 2), padding = 'same')) # pooling layer
    model.add(keras.layers.Dropout(0.1))
    model.add(keras.layers.BatchNormalization())
    
    # flattening thte CNN grid
    model.add(keras.layers.Flatten())
    
    # dense neural network layer
    model.add(keras.layers.Dense(64, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3)) # dropout to avoid overfitting
    model.add(keras.layers.BatchNormalization())
    # final softmax layer 
    model.add(keras.layers.Dense(10, activation = 'softmax'))

    return model
    

def predict(model, X, Y):
    # function to predict the output using the trained model
    X = X[np.newaxis, ...]
    
    prediction = model.predict(X)
    
    predicted_index = np.argmax(prediction, axis = 1)
    
    print(f'Target: {Y}, predicted: {predicted_index}')
    
    
if(__name__ == '__main__'):
    X_train, X_val, X_test, Y_train, Y_val, Y_test = prepare_dataset(0.25, 0.2)
    
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)
    
    optimizer = keras.optimizers.Adam(learning_rate = 0.0001)
    
    model.compile(optimizer = optimizer,
                 loss = 'sparse_categorical_crossentropy',
                 metrics = ['accuracy'])
    
    model.summary()
    
    history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size = 32, epochs = 100)
    
    plot_history(history)
    
    test_loss, test_acc = model.evaluate(X_test, Y_test, verbose = 2)
    
    print(f'Test Accuracy: {test_acc}')
    
    # X_to_predict = X_test[300]
    # Y_to_predict = Y_test[300]
    
    # predict(model, X_to_predict, Y_to_predict)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 21, 30)       300
#
#  max_pooling2d (MaxPooling2D  (None, 64, 11, 30)       0
#  )
#
#  dropout (Dropout)           (None, 64, 11, 30)        0
#
#  batch_normalization (BatchN  (None, 64, 11, 30)       120
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 62, 9, 60)         16260
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 5, 60)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 31, 5, 60)         0
#
#  batch_normalization_1 (Batc  (None, 31, 5, 60)        240
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 30, 4, 60)         14460
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 2, 60)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 15, 2, 60)         0
#
#  batch_normalization_2 (Batc  (None, 15, 2, 60)        240
#  hNormalization)
#
#  flatten (Flatten)           (None, 1800)              0
#
#  dense (Dense)               (None, 64)                115264
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 147,790
# Trainable params: 147,362
# Non-trainable params: 428
# _________________________________________________________________
# Epoch 1/100
# 188/188 [==============================] - 15s 10ms/step - loss: 2.3053 - accuracy: 0.2445 - val_loss: 1.8414 - val_accuracy: 0.3165
# Epoch 2/100
# 188/188 [==============================] - 1s 8ms/step - loss: 1.8654 - accuracy: 0.3535 - val_loss: 1.7561 - val_accuracy: 0.3686
# Epoch 3/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.6713 - accuracy: 0.3958 - val_loss: 1.6907 - val_accuracy: 0.4036
# Epoch 4/100
# 188/188 [==============================] - 1s 8ms/step - loss: 1.5273 - accuracy: 0.4473 - val_loss: 1.5559 - val_accuracy: 0.4357
# Epoch 5/100
# 188/188 [==============================] - 1s 8ms/step - loss: 1.4554 - accuracy: 0.4786 - val_loss: 1.4542 - val_accuracy: 0.4737
# Epoch 6/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.3842 - accuracy: 0.5078 - val_loss: 1.4109 - val_accuracy: 0.4832
# Epoch 7/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.3379 - accuracy: 0.5240 - val_loss: 1.3659 - val_accuracy: 0.5078
# Epoch 8/100
# 188/188 [==============================] - 1s 8ms/step - loss: 1.2808 - accuracy: 0.5435 - val_loss: 1.3489 - val_accuracy: 0.5183
# Epoch 9/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.2568 - accuracy: 0.5520 - val_loss: 1.3263 - val_accuracy: 0.5243
# Epoch 10/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.2200 - accuracy: 0.5577 - val_loss: 1.3140 - val_accuracy: 0.5083
# Epoch 11/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.1838 - accuracy: 0.5810 - val_loss: 1.2631 - val_accuracy: 0.5418
# Epoch 12/100
# 188/188 [==============================] - 1s 8ms/step - loss: 1.1586 - accuracy: 0.5877 - val_loss: 1.2557 - val_accuracy: 0.5458
# Epoch 13/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.1425 - accuracy: 0.6027 - val_loss: 1.2480 - val_accuracy: 0.5423
# Epoch 14/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.0992 - accuracy: 0.6204 - val_loss: 1.1895 - val_accuracy: 0.5709
# Epoch 15/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.0724 - accuracy: 0.6219 - val_loss: 1.1549 - val_accuracy: 0.5623
# Epoch 16/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.0662 - accuracy: 0.6323 - val_loss: 1.1550 - val_accuracy: 0.5824
# Epoch 17/100
# 188/188 [==============================] - 1s 8ms/step - loss: 1.0258 - accuracy: 0.6406 - val_loss: 1.1310 - val_accuracy: 0.5854
# Epoch 18/100
# 188/188 [==============================] - 1s 7ms/step - loss: 1.0225 - accuracy: 0.6430 - val_loss: 1.1420 - val_accuracy: 0.5844
# Epoch 19/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.9949 - accuracy: 0.6565 - val_loss: 1.1215 - val_accuracy: 0.5919
# Epoch 20/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.9764 - accuracy: 0.6575 - val_loss: 1.1054 - val_accuracy: 0.6009
# Epoch 21/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.9356 - accuracy: 0.6755 - val_loss: 0.9873 - val_accuracy: 0.6455
# Epoch 22/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.9328 - accuracy: 0.6837 - val_loss: 1.0033 - val_accuracy: 0.6395
# Epoch 23/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.9091 - accuracy: 0.6939 - val_loss: 1.0120 - val_accuracy: 0.6335
# Epoch 24/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.8841 - accuracy: 0.7071 - val_loss: 1.0535 - val_accuracy: 0.6234
# Epoch 25/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.8521 - accuracy: 0.7067 - val_loss: 0.9542 - val_accuracy: 0.6620
# Epoch 26/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.8563 - accuracy: 0.7071 - val_loss: 0.9425 - val_accuracy: 0.6640
# Epoch 27/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.8558 - accuracy: 0.7092 - val_loss: 0.9414 - val_accuracy: 0.6635
# Epoch 28/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.8203 - accuracy: 0.7189 - val_loss: 0.9438 - val_accuracy: 0.6580
# Epoch 29/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.8051 - accuracy: 0.7204 - val_loss: 0.9073 - val_accuracy: 0.6745
# Epoch 30/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.8043 - accuracy: 0.7273 - val_loss: 0.9496 - val_accuracy: 0.6520
# Epoch 31/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.7914 - accuracy: 0.7241 - val_loss: 0.9093 - val_accuracy: 0.6745
# Epoch 32/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.7827 - accuracy: 0.7383 - val_loss: 0.8678 - val_accuracy: 0.6935
# Epoch 33/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.7612 - accuracy: 0.7434 - val_loss: 0.8599 - val_accuracy: 0.6900
# Epoch 34/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.7346 - accuracy: 0.7470 - val_loss: 0.8752 - val_accuracy: 0.6845
# Epoch 35/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.7408 - accuracy: 0.7445 - val_loss: 0.8504 - val_accuracy: 0.6945
# Epoch 36/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.7134 - accuracy: 0.7520 - val_loss: 0.8208 - val_accuracy: 0.7121
# Epoch 37/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.7164 - accuracy: 0.7596 - val_loss: 0.8356 - val_accuracy: 0.7101
# Epoch 38/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.6988 - accuracy: 0.7601 - val_loss: 0.8316 - val_accuracy: 0.6970
# Epoch 39/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.6873 - accuracy: 0.7705 - val_loss: 0.8108 - val_accuracy: 0.7246
# Epoch 40/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.6849 - accuracy: 0.7683 - val_loss: 0.7926 - val_accuracy: 0.7241
# Epoch 41/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.6607 - accuracy: 0.7792 - val_loss: 0.8638 - val_accuracy: 0.6985
# Epoch 42/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.6658 - accuracy: 0.7783 - val_loss: 0.7883 - val_accuracy: 0.7281
# Epoch 43/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.6528 - accuracy: 0.7815 - val_loss: 0.7896 - val_accuracy: 0.7281
# Epoch 44/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.6250 - accuracy: 0.7942 - val_loss: 0.7725 - val_accuracy: 0.7311
# Epoch 45/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.6220 - accuracy: 0.7947 - val_loss: 0.7802 - val_accuracy: 0.7286
# Epoch 46/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.6094 - accuracy: 0.7937 - val_loss: 0.7877 - val_accuracy: 0.7226
# Epoch 47/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.6192 - accuracy: 0.7892 - val_loss: 0.8243 - val_accuracy: 0.7116
# Epoch 48/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.6069 - accuracy: 0.7905 - val_loss: 0.7616 - val_accuracy: 0.7376
# Epoch 49/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.5907 - accuracy: 0.8009 - val_loss: 0.7492 - val_accuracy: 0.7416
# Epoch 50/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.5636 - accuracy: 0.8149 - val_loss: 0.7583 - val_accuracy: 0.7371
# Epoch 51/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.5745 - accuracy: 0.8079 - val_loss: 0.7245 - val_accuracy: 0.7506
# Epoch 52/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.5560 - accuracy: 0.8152 - val_loss: 0.7369 - val_accuracy: 0.7536
# Epoch 53/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.5770 - accuracy: 0.7997 - val_loss: 0.7532 - val_accuracy: 0.7456
# Epoch 54/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.5476 - accuracy: 0.8127 - val_loss: 0.7181 - val_accuracy: 0.7551
# Epoch 55/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.5393 - accuracy: 0.8192 - val_loss: 0.7782 - val_accuracy: 0.7306
# Epoch 56/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.5316 - accuracy: 0.8159 - val_loss: 0.7855 - val_accuracy: 0.7311
# Epoch 57/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.5216 - accuracy: 0.8272 - val_loss: 0.7127 - val_accuracy: 0.7571
# Epoch 58/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.5129 - accuracy: 0.8301 - val_loss: 0.7273 - val_accuracy: 0.7576
# Epoch 59/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.5076 - accuracy: 0.8354 - val_loss: 0.7899 - val_accuracy: 0.7296
# Epoch 60/100
# 188/188 [==============================] - 2s 10ms/step - loss: 0.5161 - accuracy: 0.8256 - val_loss: 0.7611 - val_accuracy: 0.7426
# Epoch 61/100
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4931 - accuracy: 0.8332 - val_loss: 0.7452 - val_accuracy: 0.7531
# Epoch 62/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4885 - accuracy: 0.8383 - val_loss: 0.7267 - val_accuracy: 0.7536
# Epoch 63/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4805 - accuracy: 0.8381 - val_loss: 0.6888 - val_accuracy: 0.7682
# Epoch 64/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4908 - accuracy: 0.8371 - val_loss: 0.7254 - val_accuracy: 0.7631
# Epoch 65/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.4668 - accuracy: 0.8414 - val_loss: 0.7301 - val_accuracy: 0.7566
# Epoch 66/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4692 - accuracy: 0.8409 - val_loss: 0.7229 - val_accuracy: 0.7611
# Epoch 67/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.4441 - accuracy: 0.8544 - val_loss: 0.6833 - val_accuracy: 0.7727
# Epoch 68/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4618 - accuracy: 0.8453 - val_loss: 0.6944 - val_accuracy: 0.7682
# Epoch 69/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4404 - accuracy: 0.8533 - val_loss: 0.6904 - val_accuracy: 0.7677
# Epoch 70/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4546 - accuracy: 0.8484 - val_loss: 0.6929 - val_accuracy: 0.7666
# Epoch 71/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4408 - accuracy: 0.8503 - val_loss: 0.6808 - val_accuracy: 0.7656
# Epoch 72/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.4219 - accuracy: 0.8605 - val_loss: 0.6748 - val_accuracy: 0.7707
# Epoch 73/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4340 - accuracy: 0.8529 - val_loss: 0.6845 - val_accuracy: 0.7732
# Epoch 74/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4218 - accuracy: 0.8575 - val_loss: 0.6867 - val_accuracy: 0.7792
# Epoch 75/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4018 - accuracy: 0.8655 - val_loss: 0.7340 - val_accuracy: 0.7576
# Epoch 76/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4132 - accuracy: 0.8591 - val_loss: 0.6602 - val_accuracy: 0.7812
# Epoch 77/100
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4387 - accuracy: 0.8466 - val_loss: 0.6713 - val_accuracy: 0.7767
# Epoch 78/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3934 - accuracy: 0.8750 - val_loss: 0.7154 - val_accuracy: 0.7636
# Epoch 79/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3913 - accuracy: 0.8700 - val_loss: 0.7044 - val_accuracy: 0.7702
# Epoch 80/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3821 - accuracy: 0.8813 - val_loss: 0.6672 - val_accuracy: 0.7817
# Epoch 81/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3910 - accuracy: 0.8715 - val_loss: 0.6803 - val_accuracy: 0.7792
# Epoch 82/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3905 - accuracy: 0.8685 - val_loss: 0.6504 - val_accuracy: 0.7857
# Epoch 83/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3824 - accuracy: 0.8740 - val_loss: 0.7045 - val_accuracy: 0.7677
# Epoch 84/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3733 - accuracy: 0.8743 - val_loss: 0.6769 - val_accuracy: 0.7842
# Epoch 85/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3757 - accuracy: 0.8760 - val_loss: 0.7017 - val_accuracy: 0.7777
# Epoch 86/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.3536 - accuracy: 0.8795 - val_loss: 0.6708 - val_accuracy: 0.7822
# Epoch 87/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.3429 - accuracy: 0.8862 - val_loss: 0.6644 - val_accuracy: 0.7872
# Epoch 88/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.3433 - accuracy: 0.8815 - val_loss: 0.6665 - val_accuracy: 0.7812
# Epoch 89/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3376 - accuracy: 0.8893 - val_loss: 0.6727 - val_accuracy: 0.7837
# Epoch 90/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3667 - accuracy: 0.8728 - val_loss: 0.6548 - val_accuracy: 0.7867
# Epoch 91/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3327 - accuracy: 0.8898 - val_loss: 0.6596 - val_accuracy: 0.7882
# Epoch 92/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3485 - accuracy: 0.8835 - val_loss: 0.6781 - val_accuracy: 0.7802
# Epoch 93/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3321 - accuracy: 0.8865 - val_loss: 0.6667 - val_accuracy: 0.7872
# Epoch 94/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3097 - accuracy: 0.8958 - val_loss: 0.6503 - val_accuracy: 0.7987
# Epoch 95/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.3231 - accuracy: 0.8925 - val_loss: 0.6619 - val_accuracy: 0.7897
# Epoch 96/100
# 188/188 [==============================] - 1s 8ms/step - loss: 0.3287 - accuracy: 0.8903 - val_loss: 0.6276 - val_accuracy: 0.7947
# Epoch 97/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3246 - accuracy: 0.8898 - val_loss: 0.6606 - val_accuracy: 0.7907
# Epoch 98/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3114 - accuracy: 0.8952 - val_loss: 0.6600 - val_accuracy: 0.7922
# Epoch 99/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3071 - accuracy: 0.8942 - val_loss: 0.7710 - val_accuracy: 0.7511
# Epoch 100/100
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3120 - accuracy: 0.8972 - val_loss: 0.6334 - val_accuracy: 0.7952
# 63/63 - 0s - loss: 0.6155 - accuracy: 0.8018 - 262ms/epoch - 4ms/step
# Test Accuracy: 0.8018018007278442
