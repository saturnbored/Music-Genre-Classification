# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATA_PATH = 'data.json' # path of the file which has the processed data stored in JSON format

def load_data(data_path):
    '''
    function to load data from the JSON file
    param: data_path -> string -> the path of the JSON file which will be used to load data
    return: X -> ndarray -> the extracted input features from the loaded file
            Y -> ndarray -> the expected output for the corresponding inputs in X
    '''
    
    with open(data_path, 'r') as fp:
        data = json.load(fp)
    
    # converting list to ndarrays
    X = np.array(data['mfcc'])
    Y = np.array(data['labels'])
    print('Data Loaded Successfully!')
    
    return X, Y

X, Y = load_data(DATA_PATH) # loading data to X and Y

def plot_history(history):
    # function to plot the history of the training of the model
    
    fig, axs = plt.subplots(2)
    
    # plotting accuracy history of training and validation datasets
    axs[0].plot(history.history["accuracy"], label = 'train-accuracy')
    axs[0].plot(history.history["val_accuracy"], label = 'validation-accuracy')
    axs[0].set_ylabel('accuracy')
    axs[0].set_xlabel('epochs')
    axs[0].legend(loc = 'lower right')
    axs[0].set_title('Accuracy Evaluation')
    
    # plotting error history of training and validation datasets
    axs[1].plot(history.history["loss"], label = 'training-loss')
    axs[1].plot(history.history["val_loss"], label = 'validation-loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].legend('upper right')
    axs[1].set_title('Loss Evaluation')
    
    plt.show()
    
def prepare_dataset(validation_size, test_size):
    # function to split the dataset into traning, validation and test sets
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_size)
    X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = validation_size)
    X_train = X_train[..., np.newaxis]
    X_val = X_val[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    return X_train, X_val, X_test, Y_train, Y_val, Y_test

def build_model(input_shape):
    # building a Convolutional Neural Network
    model = keras.Sequential()
    
    #adding convolutional and pooling layers to the model
    model.add(keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = input_shape)) # convoluition layer
    model.add(keras.layers.MaxPooling2D((3, 3), strides = (2, 2), padding = 'same')) # pooling layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation = 'relu')) # convolution layer
    model.add(keras.layers.MaxPooling2D((3, 3), strides = (2, 2), padding = 'same')) # pooling layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation = 'relu')) # convolution layer
    model.add(keras.layers.MaxPooling2D((2, 2), strides = (2, 2), padding = 'same')) # pooling layer
    model.add(keras.layers.BatchNormalization())
    
    # flattening thte CNN grid
    model.add(keras.layers.Flatten())
    
    # dense neural network layer
    model.add(keras.layers.Dense(64, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3)) # dropout to avoid overfitting
    # final softmax layer 
    model.add(keras.layers.Dense(10, activation = 'softmax'))

    return model
# Out:
# Data Loaded Successfully!

# %%
def predict(model, X, Y):
    # function to predict the output using the trained model
    X = X[np.newaxis, ...]
    
    prediction = model.predict(X)
    
    predicted_index = np.argmax(prediction, axis = 1)
    
    print(f'Target: {Y}, predicted: {predicted_index}')
    
    
if(__name__ == '__main__'):
    X_train, X_val, X_test, Y_train, Y_val, Y_test = prepare_dataset(0.25, 0.2)
    
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)
    
    optimizer = keras.optimizers.Adam(learning_rate = 0.0001)
    
    model.compile(optimizer = optimizer,
                 loss = 'sparse_categorical_crossentropy',
                 metrics = ['accuracy'])
    
    model.summary()
    
    history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size = 32, epochs = 50)
    
    plot_history(history)
    
    test_loss, test_acc = model.evaluate(X_test, Y_test, verbose = 2)
    
    print(f'Test Accuracy: {test_acc}')
    
    X_to_predict = X_test[300]
    Y_to_predict = Y_test[300]
    
    predict(model, X_to_predict, Y_to_predict)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 128, 11, 32)       320
#
#  max_pooling2d_6 (MaxPooling  (None, 64, 6, 32)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 62, 4, 32)         9248
#
#  max_pooling2d_7 (MaxPooling  (None, 31, 2, 32)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 30, 1, 32)         4128
#
#  max_pooling2d_8 (MaxPooling  (None, 15, 1, 32)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 15, 1, 32)        128
#  hNormalization)
#
#  flatten_2 (Flatten)         (None, 480)               0
#
#  dense_4 (Dense)             (None, 64)                30784
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 45,258
# Trainable params: 45,194
# Non-trainable params: 64
# _________________________________________________________________
# Epoch 1/50
# 188/188 [==============================] - 7s 32ms/step - loss: 2.2936 - accuracy: 0.2227 - val_loss: 1.9144 - val_accuracy: 0.3090
# Epoch 2/50
# 188/188 [==============================] - 6s 33ms/step - loss: 1.7789 - accuracy: 0.3622 - val_loss: 1.5613 - val_accuracy: 0.4331
# Epoch 3/50
# 188/188 [==============================] - 8s 40ms/step - loss: 1.6096 - accuracy: 0.4208 - val_loss: 1.4900 - val_accuracy: 0.4592
# Epoch 4/50
# 188/188 [==============================] - 7s 38ms/step - loss: 1.5073 - accuracy: 0.4515 - val_loss: 1.3719 - val_accuracy: 0.5088
# Epoch 5/50
# 188/188 [==============================] - 7s 37ms/step - loss: 1.4246 - accuracy: 0.4807 - val_loss: 1.3072 - val_accuracy: 0.5233
# Epoch 6/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.3802 - accuracy: 0.5006 - val_loss: 1.2549 - val_accuracy: 0.5538
# Epoch 7/50
# 188/188 [==============================] - 8s 41ms/step - loss: 1.3117 - accuracy: 0.5273 - val_loss: 1.2154 - val_accuracy: 0.5618
# Epoch 8/50
# 188/188 [==============================] - 7s 38ms/step - loss: 1.2637 - accuracy: 0.5500 - val_loss: 1.1931 - val_accuracy: 0.5709
# Epoch 9/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.2287 - accuracy: 0.5605 - val_loss: 1.1999 - val_accuracy: 0.5819
# Epoch 10/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.1838 - accuracy: 0.5759 - val_loss: 1.1293 - val_accuracy: 0.6029
# Epoch 11/50
# 188/188 [==============================] - 7s 38ms/step - loss: 1.1556 - accuracy: 0.5949 - val_loss: 1.0682 - val_accuracy: 0.6244
# Epoch 12/50
# 188/188 [==============================] - 8s 40ms/step - loss: 1.1172 - accuracy: 0.6057 - val_loss: 1.1365 - val_accuracy: 0.5839
# Epoch 13/50
# 188/188 [==============================] - 8s 40ms/step - loss: 1.0894 - accuracy: 0.6133 - val_loss: 1.0661 - val_accuracy: 0.6209
# Epoch 14/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.0777 - accuracy: 0.6196 - val_loss: 1.0148 - val_accuracy: 0.6520
# Epoch 15/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.0470 - accuracy: 0.6326 - val_loss: 1.0372 - val_accuracy: 0.6229
# Epoch 16/50
# 188/188 [==============================] - 8s 44ms/step - loss: 1.0022 - accuracy: 0.6486 - val_loss: 0.9520 - val_accuracy: 0.6605
# Epoch 17/50
# 188/188 [==============================] - 8s 42ms/step - loss: 0.9951 - accuracy: 0.6498 - val_loss: 1.0277 - val_accuracy: 0.6324
# Epoch 18/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.9841 - accuracy: 0.6536 - val_loss: 1.0139 - val_accuracy: 0.6395
# Epoch 19/50
# 188/188 [==============================] - 7s 39ms/step - loss: 0.9462 - accuracy: 0.6673 - val_loss: 0.9628 - val_accuracy: 0.6665
# Epoch 20/50
# 188/188 [==============================] - 7s 39ms/step - loss: 0.9465 - accuracy: 0.6698 - val_loss: 0.9828 - val_accuracy: 0.6535
# Epoch 21/50
# 188/188 [==============================] - 7s 38ms/step - loss: 0.9163 - accuracy: 0.6787 - val_loss: 1.0018 - val_accuracy: 0.6525
# Epoch 22/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.8912 - accuracy: 0.6884 - val_loss: 0.9885 - val_accuracy: 0.6575
# Epoch 23/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.8788 - accuracy: 0.6950 - val_loss: 0.9237 - val_accuracy: 0.6740
# Epoch 24/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.8678 - accuracy: 0.7036 - val_loss: 0.9167 - val_accuracy: 0.6720
# Epoch 25/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.8582 - accuracy: 0.7054 - val_loss: 0.8752 - val_accuracy: 0.6985
# Epoch 26/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.8351 - accuracy: 0.7131 - val_loss: 0.9500 - val_accuracy: 0.6670
# Epoch 27/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.7959 - accuracy: 0.7241 - val_loss: 0.8473 - val_accuracy: 0.7031
# Epoch 28/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.7950 - accuracy: 0.7212 - val_loss: 0.9252 - val_accuracy: 0.6690
# Epoch 29/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.7717 - accuracy: 0.7309 - val_loss: 0.9106 - val_accuracy: 0.6800
# Epoch 30/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.7720 - accuracy: 0.7289 - val_loss: 0.8787 - val_accuracy: 0.6970
# Epoch 31/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.7569 - accuracy: 0.7348 - val_loss: 0.9380 - val_accuracy: 0.6670
# Epoch 32/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.7307 - accuracy: 0.7493 - val_loss: 1.1690 - val_accuracy: 0.6054
# Epoch 33/50
# 188/188 [==============================] - 7s 38ms/step - loss: 0.7412 - accuracy: 0.7371 - val_loss: 0.8730 - val_accuracy: 0.6910
# Epoch 34/50
# 188/188 [==============================] - 7s 38ms/step - loss: 0.7225 - accuracy: 0.7526 - val_loss: 0.8622 - val_accuracy: 0.6925
# Epoch 35/50
# 188/188 [==============================] - 7s 38ms/step - loss: 0.7137 - accuracy: 0.7568 - val_loss: 0.8070 - val_accuracy: 0.7126
# Epoch 36/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.6905 - accuracy: 0.7631 - val_loss: 0.9633 - val_accuracy: 0.6625
# Epoch 37/50
# 188/188 [==============================] - 7s 39ms/step - loss: 0.6838 - accuracy: 0.7616 - val_loss: 0.8548 - val_accuracy: 0.6935
# Epoch 38/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.6712 - accuracy: 0.7658 - val_loss: 0.8549 - val_accuracy: 0.6910
# Epoch 39/50
# 188/188 [==============================] - 7s 38ms/step - loss: 0.6504 - accuracy: 0.7693 - val_loss: 0.7963 - val_accuracy: 0.7186
# Epoch 40/50
# 188/188 [==============================] - 7s 38ms/step - loss: 0.6538 - accuracy: 0.7723 - val_loss: 0.7950 - val_accuracy: 0.7216
# Epoch 41/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.6388 - accuracy: 0.7833 - val_loss: 0.8048 - val_accuracy: 0.7216
# Epoch 42/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.6210 - accuracy: 0.7905 - val_loss: 0.8238 - val_accuracy: 0.7091
# Epoch 43/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.6224 - accuracy: 0.7845 - val_loss: 0.8611 - val_accuracy: 0.6990
# Epoch 44/50
# 188/188 [==============================] - 7s 38ms/step - loss: 0.6186 - accuracy: 0.7825 - val_loss: 0.8617 - val_accuracy: 0.6995
# Epoch 45/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.5930 - accuracy: 0.7940 - val_loss: 0.8538 - val_accuracy: 0.7136
# Epoch 46/50
# 188/188 [==============================] - 7s 39ms/step - loss: 0.5928 - accuracy: 0.7929 - val_loss: 0.8757 - val_accuracy: 0.6995
# Epoch 47/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.5741 - accuracy: 0.7994 - val_loss: 0.9774 - val_accuracy: 0.6755
# Epoch 48/50
# 188/188 [==============================] - 8s 42ms/step - loss: 0.5738 - accuracy: 0.8010 - val_loss: 0.8475 - val_accuracy: 0.7006
# Epoch 49/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.5696 - accuracy: 0.8002 - val_loss: 0.8540 - val_accuracy: 0.6950
# Epoch 50/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.5576 - accuracy: 0.8082 - val_loss: 0.9499 - val_accuracy: 0.6720
# 63/63 - 1s - loss: 0.9557 - accuracy: 0.6922 - 519ms/epoch - 8ms/step
# Test Accuracy: 0.6921921968460083
# 1/1 [==============================] - 0s 121ms/step
# Target: 0, predicted: [0]
