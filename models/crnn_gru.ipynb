# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix
from seaborn import heatmap

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-3-17bb7203622b>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
DATA_PATH = '/content/gdrive/MyDrive/Colab Notebooks/data2.json' # path of the file which has the processed data stored in JSON format

def load_data(data_path):
    '''
    function to load data from the JSON file
    param: data_path -> string -> the path of the JSON file which will be used to load data
    return: X -> ndarray -> the extracted input features from the loaded file
            Y -> ndarray -> the expected output for the corresponding inputs in X
    '''
    
    with open(data_path, "r") as fp:
        data = json.load(fp)
    
    # converting list to ndarrays
    X = np.array(data['mfcc'])
    Y = np.array(data['labels'])
    mappings = data['mappings']
    print('Data Loaded Successfully!')
    
    return X, Y, mappings

X, Y, mappings = load_data(DATA_PATH) # loading data to X and Y

def plot_history(history):
    # function to plot the history of the training of the model
    
    fig, axs = plt.subplots(2)
    
    # plotting accuracy history of training and validation datasets
    axs[0].plot(history.history["accuracy"], label = 'train-accuracy')
    axs[0].plot(history.history["val_accuracy"], label = 'validation-accuracy')
    axs[0].set_ylabel('accuracy')
    axs[0].set_xlabel('epochs')
    axs[0].legend(loc = 'lower right')
    axs[0].set_title('Accuracy Evaluation')
    
    # plotting error history of training and validation datasets
    axs[1].plot(history.history["loss"], label = 'training-loss')
    axs[1].plot(history.history["val_loss"], label = 'validation-loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].legend('upper right')
    axs[1].set_title('Loss Evaluation')
    
    plt.show()
    
def prepare_dataset(validation_size, test_size):
    # function to split the dataset into traning, validation and test sets
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_size)
    X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = validation_size)
    X_train = X_train[..., np.newaxis]
    X_val = X_val[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    return X_train, X_val, X_test, Y_train, Y_val, Y_test
# Out:
# Data Loaded Successfully!

# %%
def build_model(input_shape):
    # building a RNN-LSTM model
    model = keras.Sequential()
    
    # adding Convolutional layers
    cnn = keras.layers.Conv2D(30, (3, 3), activation = 'relu', input_shape = input_shape)
    model.add(cnn)
    
    cnn = keras.layers.MaxPooling2D((2, 2), padding = 'same')
    model.add(cnn)

    cnn = keras.layers.Dropout(0.1)
    model.add(cnn)
    model.add(keras.layers.BatchNormalization())

    cnn = keras.layers.Conv2D(60, (3, 3), activation = 'relu')
    model.add(cnn)
    
    cnn = keras.layers.MaxPooling2D((3, 3), strides = (2, 2), padding = 'same')
    model.add(cnn)
    
    cnn = keras.layers.Dropout(0.1)
    model.add(cnn)
    model.add(keras.layers.BatchNormalization())

    cnn = keras.layers.Conv2D(60, (3, 3), activation = 'relu')
    model.add(cnn)
    
    cnn = keras.layers.MaxPooling2D((4, 4), strides = (2, 2), padding = 'same')
    model.add(cnn)
    
    cnn = keras.layers.Dropout(0.1)
    model.add(cnn)
    model.add(keras.layers.BatchNormalization())

    output_shape = cnn.output_shape
    
    # reshaping the dimensions to shift from cnn to rnn
    reshape = keras.layers.Reshape(target_shape = (output_shape[1], int(output_shape[2] * output_shape[3])))
    model.add(reshape)

    output_shape = reshape.output_shape
    
    rnn = keras.layers.GRU(20, return_sequences = True)
    model.add(rnn)
    
    rnn = keras.layers.GRU(20)
    model.add(rnn)
    
    output_shape = rnn.output_shape
    
    last = keras.layers.Dense(10, activation = 'softmax')
    model.add(last)
    

    return model

def plot_confusion_matrix(actual_classes : np.array, predicted_classes : np.array, sorted_labels : list):

    matrix = confusion_matrix(actual_classes, predicted_classes, labels=sorted_labels)
    
    plt.figure(figsize=(12.8,6))
    heatmap(matrix, annot=True, xticklabels=sorted_labels, yticklabels=sorted_labels, cmap="Blues", fmt="g")
    plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix')

    plt.show()

if(__name__ == '__main__'):
    X_train, X_val, X_test, Y_train, Y_val, Y_test = prepare_dataset(0.25, 0.2)
    print(X_train.shape, Y_train.shape)
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    print(input_shape)
    model = build_model(input_shape)
    
    optimizer = keras.optimizers.Adam(learning_rate = 0.0001)
    
    model.compile(optimizer = optimizer,
                 loss = 'sparse_categorical_crossentropy',
                 metrics = ['accuracy'])
    
    model.summary()
    
    history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size = 32, epochs = 250)
    
    plot_history(history)
    
    predictions = model.predict(X_test).tolist()

    
    predicted_classes = [np.array(xi).argmax() for xi in predictions]

    

    test_accuracy = accuracy_score(predicted_classes, Y_test)
    
    print(f'Test Accuracy: {test_accuracy}')

    
    predicted_classes = [mappings[np.array(xi).argmax()] for xi in predictions]
    Y_test_classes = [mappings[di] for di in Y_test]
    plot_confusion_matrix(Y_test_classes, predicted_classes, mappings)
# Out:
# (5991, 130, 23, 1) (5991,)
# (130, 23, 1)
# (None, 15, 2, 60)
# (None, 15, 120)
# (None, 15, 120)
# (None, 20)
# (None, 10)
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 128, 21, 30)       300
#
#  max_pooling2d_18 (MaxPoolin  (None, 64, 11, 30)       0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 64, 11, 30)        0
#
#  batch_normalization_18 (Bat  (None, 64, 11, 30)       120
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 62, 9, 60)         16260
#
#  max_pooling2d_19 (MaxPoolin  (None, 31, 5, 60)        0
#  g2D)
#
#  dropout_19 (Dropout)        (None, 31, 5, 60)         0
#
#  batch_normalization_19 (Bat  (None, 31, 5, 60)        240
#  chNormalization)
#
#  conv2d_20 (Conv2D)          (None, 29, 3, 60)         32460
#
#  max_pooling2d_20 (MaxPoolin  (None, 15, 2, 60)        0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 15, 2, 60)         0
#
#  batch_normalization_20 (Bat  (None, 15, 2, 60)        240
#  chNormalization)
#
#  reshape_6 (Reshape)         (None, 15, 120)           0
#
#  gru_12 (GRU)                (None, 15, 20)            8520
#
#  gru_13 (GRU)                (None, 20)                2520
#
#  dense_6 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 60,870
# Trainable params: 60,570
# Non-trainable params: 300
# _________________________________________________________________
# Epoch 1/250
# 188/188 [==============================] - 5s 12ms/step - loss: 2.0752 - accuracy: 0.2654 - val_loss: 1.9404 - val_accuracy: 0.3475
# Epoch 2/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.8264 - accuracy: 0.3968 - val_loss: 1.7927 - val_accuracy: 0.3986
# Epoch 3/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.6724 - accuracy: 0.4457 - val_loss: 1.6904 - val_accuracy: 0.4211
# Epoch 4/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.5636 - accuracy: 0.4822 - val_loss: 1.6178 - val_accuracy: 0.4417
# Epoch 5/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.4659 - accuracy: 0.5131 - val_loss: 1.5493 - val_accuracy: 0.4752
# Epoch 6/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.3887 - accuracy: 0.5480 - val_loss: 1.5110 - val_accuracy: 0.4887
# Epoch 7/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.3226 - accuracy: 0.5690 - val_loss: 1.4254 - val_accuracy: 0.5158
# Epoch 8/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.2622 - accuracy: 0.5887 - val_loss: 1.3784 - val_accuracy: 0.5218
# Epoch 9/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.2127 - accuracy: 0.6089 - val_loss: 1.3517 - val_accuracy: 0.5333
# Epoch 10/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.1546 - accuracy: 0.6328 - val_loss: 1.2552 - val_accuracy: 0.5774
# Epoch 11/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.1196 - accuracy: 0.6411 - val_loss: 1.2837 - val_accuracy: 0.5523
# Epoch 12/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.0773 - accuracy: 0.6553 - val_loss: 1.2131 - val_accuracy: 0.5849
# Epoch 13/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.0321 - accuracy: 0.6800 - val_loss: 1.2446 - val_accuracy: 0.5674
# Epoch 14/250
# 188/188 [==============================] - 2s 9ms/step - loss: 1.0105 - accuracy: 0.6834 - val_loss: 1.1840 - val_accuracy: 0.5939
# Epoch 15/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.9752 - accuracy: 0.6907 - val_loss: 1.1929 - val_accuracy: 0.5949
# Epoch 16/250
# 188/188 [==============================] - 2s 11ms/step - loss: 0.9477 - accuracy: 0.7062 - val_loss: 1.1334 - val_accuracy: 0.6154
# Epoch 17/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.9107 - accuracy: 0.7166 - val_loss: 1.1980 - val_accuracy: 0.5834
# Epoch 18/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8923 - accuracy: 0.7166 - val_loss: 1.0185 - val_accuracy: 0.6560
# Epoch 19/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8602 - accuracy: 0.7266 - val_loss: 1.0915 - val_accuracy: 0.6269
# Epoch 20/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8474 - accuracy: 0.7329 - val_loss: 1.0549 - val_accuracy: 0.6405
# Epoch 21/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8163 - accuracy: 0.7441 - val_loss: 1.0357 - val_accuracy: 0.6500
# Epoch 22/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8004 - accuracy: 0.7451 - val_loss: 0.9951 - val_accuracy: 0.6595
# Epoch 23/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.7834 - accuracy: 0.7536 - val_loss: 1.0429 - val_accuracy: 0.6385
# Epoch 24/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.7563 - accuracy: 0.7616 - val_loss: 0.9852 - val_accuracy: 0.6670
# Epoch 25/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.7523 - accuracy: 0.7658 - val_loss: 0.9673 - val_accuracy: 0.6770
# Epoch 26/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.7335 - accuracy: 0.7661 - val_loss: 0.9515 - val_accuracy: 0.6775
# Epoch 27/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.7104 - accuracy: 0.7713 - val_loss: 1.0630 - val_accuracy: 0.6335
# Epoch 28/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.7035 - accuracy: 0.7740 - val_loss: 1.0206 - val_accuracy: 0.6530
# Epoch 29/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.6794 - accuracy: 0.7848 - val_loss: 0.9298 - val_accuracy: 0.6875
# Epoch 30/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.6649 - accuracy: 0.7858 - val_loss: 0.8898 - val_accuracy: 0.7066
# Epoch 31/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.6539 - accuracy: 0.7900 - val_loss: 0.8870 - val_accuracy: 0.7106
# Epoch 32/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.6429 - accuracy: 0.7932 - val_loss: 0.7998 - val_accuracy: 0.7401
# Epoch 33/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.6217 - accuracy: 0.7985 - val_loss: 0.9772 - val_accuracy: 0.6730
# Epoch 34/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.6194 - accuracy: 0.8025 - val_loss: 0.8245 - val_accuracy: 0.7256
# Epoch 35/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.6133 - accuracy: 0.7970 - val_loss: 0.8628 - val_accuracy: 0.7091
# Epoch 36/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5936 - accuracy: 0.8084 - val_loss: 0.7900 - val_accuracy: 0.7466
# Epoch 37/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5930 - accuracy: 0.8064 - val_loss: 0.8706 - val_accuracy: 0.7081
# Epoch 38/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5771 - accuracy: 0.8137 - val_loss: 0.8580 - val_accuracy: 0.7191
# Epoch 39/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5785 - accuracy: 0.8146 - val_loss: 0.8784 - val_accuracy: 0.6975
# Epoch 40/250
# 188/188 [==============================] - 2s 11ms/step - loss: 0.5646 - accuracy: 0.8174 - val_loss: 0.8826 - val_accuracy: 0.7126
# Epoch 41/250
# 188/188 [==============================] - 2s 12ms/step - loss: 0.5562 - accuracy: 0.8206 - val_loss: 0.8709 - val_accuracy: 0.7136
# Epoch 42/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5447 - accuracy: 0.8284 - val_loss: 0.8332 - val_accuracy: 0.7276
# Epoch 43/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5362 - accuracy: 0.8229 - val_loss: 0.7193 - val_accuracy: 0.7661
# Epoch 44/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5299 - accuracy: 0.8286 - val_loss: 0.7918 - val_accuracy: 0.7426
# Epoch 45/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5006 - accuracy: 0.8379 - val_loss: 0.8064 - val_accuracy: 0.7386
# Epoch 46/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5144 - accuracy: 0.8329 - val_loss: 0.7666 - val_accuracy: 0.7561
# Epoch 47/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4987 - accuracy: 0.8379 - val_loss: 0.7989 - val_accuracy: 0.7386
# Epoch 48/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4802 - accuracy: 0.8464 - val_loss: 0.7430 - val_accuracy: 0.7581
# Epoch 49/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4914 - accuracy: 0.8393 - val_loss: 0.7826 - val_accuracy: 0.7471
# Epoch 50/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4940 - accuracy: 0.8391 - val_loss: 0.7944 - val_accuracy: 0.7411
# Epoch 51/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4676 - accuracy: 0.8488 - val_loss: 0.7233 - val_accuracy: 0.7712
# Epoch 52/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4633 - accuracy: 0.8463 - val_loss: 0.6992 - val_accuracy: 0.7697
# Epoch 53/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4587 - accuracy: 0.8531 - val_loss: 0.8120 - val_accuracy: 0.7381
# Epoch 54/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4466 - accuracy: 0.8531 - val_loss: 0.7591 - val_accuracy: 0.7451
# Epoch 55/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4478 - accuracy: 0.8543 - val_loss: 0.7691 - val_accuracy: 0.7511
# Epoch 56/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4411 - accuracy: 0.8553 - val_loss: 0.8361 - val_accuracy: 0.7336
# Epoch 57/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4368 - accuracy: 0.8603 - val_loss: 0.7872 - val_accuracy: 0.7416
# Epoch 58/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4324 - accuracy: 0.8536 - val_loss: 0.7189 - val_accuracy: 0.7742
# Epoch 59/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4148 - accuracy: 0.8643 - val_loss: 0.7703 - val_accuracy: 0.7491
# Epoch 60/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4297 - accuracy: 0.8621 - val_loss: 0.8049 - val_accuracy: 0.7456
# Epoch 61/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4128 - accuracy: 0.8635 - val_loss: 0.6550 - val_accuracy: 0.7897
# Epoch 62/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4073 - accuracy: 0.8665 - val_loss: 0.7325 - val_accuracy: 0.7677
# Epoch 63/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4076 - accuracy: 0.8651 - val_loss: 0.6865 - val_accuracy: 0.7762
# Epoch 64/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4011 - accuracy: 0.8735 - val_loss: 0.7737 - val_accuracy: 0.7571
# Epoch 65/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3991 - accuracy: 0.8688 - val_loss: 0.7002 - val_accuracy: 0.7722
# Epoch 66/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3921 - accuracy: 0.8726 - val_loss: 0.7365 - val_accuracy: 0.7616
# Epoch 67/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3881 - accuracy: 0.8708 - val_loss: 0.7250 - val_accuracy: 0.7687
# Epoch 68/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3861 - accuracy: 0.8746 - val_loss: 0.6723 - val_accuracy: 0.7817
# Epoch 69/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3800 - accuracy: 0.8731 - val_loss: 0.6690 - val_accuracy: 0.7772
# Epoch 70/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3652 - accuracy: 0.8793 - val_loss: 0.6953 - val_accuracy: 0.7787
# Epoch 71/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3658 - accuracy: 0.8792 - val_loss: 0.7049 - val_accuracy: 0.7677
# Epoch 72/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3577 - accuracy: 0.8832 - val_loss: 0.6664 - val_accuracy: 0.7852
# Epoch 73/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3645 - accuracy: 0.8807 - val_loss: 0.6512 - val_accuracy: 0.7912
# Epoch 74/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3706 - accuracy: 0.8771 - val_loss: 0.6909 - val_accuracy: 0.7742
# Epoch 75/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3556 - accuracy: 0.8828 - val_loss: 0.6811 - val_accuracy: 0.7837
# Epoch 76/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3377 - accuracy: 0.8888 - val_loss: 0.6499 - val_accuracy: 0.7912
# Epoch 77/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3356 - accuracy: 0.8948 - val_loss: 0.6603 - val_accuracy: 0.7952
# Epoch 78/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3343 - accuracy: 0.8902 - val_loss: 0.7563 - val_accuracy: 0.7697
# Epoch 79/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3326 - accuracy: 0.8928 - val_loss: 0.7118 - val_accuracy: 0.7782
# Epoch 80/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3290 - accuracy: 0.8942 - val_loss: 0.5757 - val_accuracy: 0.8157
# Epoch 81/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3182 - accuracy: 0.8967 - val_loss: 0.6434 - val_accuracy: 0.8017
# Epoch 82/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3226 - accuracy: 0.8967 - val_loss: 0.6357 - val_accuracy: 0.7947
# Epoch 83/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3260 - accuracy: 0.8913 - val_loss: 0.7448 - val_accuracy: 0.7692
# Epoch 84/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3128 - accuracy: 0.8985 - val_loss: 0.6496 - val_accuracy: 0.7977
# Epoch 85/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2995 - accuracy: 0.9022 - val_loss: 0.6140 - val_accuracy: 0.8097
# Epoch 86/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3044 - accuracy: 0.8992 - val_loss: 0.5901 - val_accuracy: 0.8132
# Epoch 87/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.3160 - accuracy: 0.8953 - val_loss: 0.6728 - val_accuracy: 0.7882
# Epoch 88/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3109 - accuracy: 0.8987 - val_loss: 0.6241 - val_accuracy: 0.8097
# Epoch 89/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2971 - accuracy: 0.9049 - val_loss: 0.6243 - val_accuracy: 0.8107
# Epoch 90/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2857 - accuracy: 0.9089 - val_loss: 0.6115 - val_accuracy: 0.8132
# Epoch 91/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2898 - accuracy: 0.9027 - val_loss: 0.6774 - val_accuracy: 0.7927
# Epoch 92/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2870 - accuracy: 0.9077 - val_loss: 0.6491 - val_accuracy: 0.8002
# Epoch 93/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2847 - accuracy: 0.9039 - val_loss: 0.6649 - val_accuracy: 0.7922
# Epoch 94/250
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2846 - accuracy: 0.9044 - val_loss: 0.6416 - val_accuracy: 0.8012
# Epoch 95/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2734 - accuracy: 0.9107 - val_loss: 0.6001 - val_accuracy: 0.8162
# Epoch 96/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2698 - accuracy: 0.9144 - val_loss: 0.6205 - val_accuracy: 0.8017
# Epoch 97/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2694 - accuracy: 0.9122 - val_loss: 0.5829 - val_accuracy: 0.8162
# Epoch 98/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2781 - accuracy: 0.9120 - val_loss: 0.7302 - val_accuracy: 0.7787
# Epoch 99/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2662 - accuracy: 0.9157 - val_loss: 0.5641 - val_accuracy: 0.8232
# Epoch 100/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2566 - accuracy: 0.9174 - val_loss: 0.6622 - val_accuracy: 0.8002
# Epoch 101/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2643 - accuracy: 0.9097 - val_loss: 0.6612 - val_accuracy: 0.8002
# Epoch 102/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2558 - accuracy: 0.9140 - val_loss: 0.6726 - val_accuracy: 0.7977
# Epoch 103/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2481 - accuracy: 0.9155 - val_loss: 0.6003 - val_accuracy: 0.8127
# Epoch 104/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2542 - accuracy: 0.9175 - val_loss: 0.6113 - val_accuracy: 0.8067
# Epoch 105/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2576 - accuracy: 0.9152 - val_loss: 0.6197 - val_accuracy: 0.8112
# Epoch 106/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2480 - accuracy: 0.9180 - val_loss: 0.5854 - val_accuracy: 0.8212
# Epoch 107/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2418 - accuracy: 0.9192 - val_loss: 0.6297 - val_accuracy: 0.8092
# Epoch 108/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2532 - accuracy: 0.9155 - val_loss: 0.6342 - val_accuracy: 0.8037
# Epoch 109/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2378 - accuracy: 0.9217 - val_loss: 0.6227 - val_accuracy: 0.8117
# Epoch 110/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2310 - accuracy: 0.9239 - val_loss: 0.6404 - val_accuracy: 0.8082
# Epoch 111/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2310 - accuracy: 0.9219 - val_loss: 0.6269 - val_accuracy: 0.8107
# Epoch 112/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2256 - accuracy: 0.9261 - val_loss: 0.6100 - val_accuracy: 0.8227
# Epoch 113/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2255 - accuracy: 0.9254 - val_loss: 0.6417 - val_accuracy: 0.8092
# Epoch 114/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2264 - accuracy: 0.9267 - val_loss: 0.6670 - val_accuracy: 0.7967
# Epoch 115/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2205 - accuracy: 0.9286 - val_loss: 0.6528 - val_accuracy: 0.8017
# Epoch 116/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2181 - accuracy: 0.9331 - val_loss: 0.6340 - val_accuracy: 0.8127
# Epoch 117/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2126 - accuracy: 0.9307 - val_loss: 0.5899 - val_accuracy: 0.8217
# Epoch 118/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2109 - accuracy: 0.9314 - val_loss: 0.7089 - val_accuracy: 0.7892
# Epoch 119/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2103 - accuracy: 0.9317 - val_loss: 0.6393 - val_accuracy: 0.8047
# Epoch 120/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2163 - accuracy: 0.9291 - val_loss: 0.6005 - val_accuracy: 0.8227
# Epoch 121/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2165 - accuracy: 0.9297 - val_loss: 0.5673 - val_accuracy: 0.8257
# Epoch 122/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2133 - accuracy: 0.9297 - val_loss: 0.5898 - val_accuracy: 0.8232
# Epoch 123/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2135 - accuracy: 0.9277 - val_loss: 0.6355 - val_accuracy: 0.8102
# Epoch 124/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2101 - accuracy: 0.9269 - val_loss: 0.6230 - val_accuracy: 0.8137
# Epoch 125/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2024 - accuracy: 0.9332 - val_loss: 0.6469 - val_accuracy: 0.8162
# Epoch 126/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1980 - accuracy: 0.9379 - val_loss: 0.5653 - val_accuracy: 0.8262
# Epoch 127/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1970 - accuracy: 0.9352 - val_loss: 0.6081 - val_accuracy: 0.8262
# Epoch 128/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2007 - accuracy: 0.9337 - val_loss: 0.6136 - val_accuracy: 0.8207
# Epoch 129/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1949 - accuracy: 0.9394 - val_loss: 0.6577 - val_accuracy: 0.8092
# Epoch 130/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1939 - accuracy: 0.9356 - val_loss: 0.5566 - val_accuracy: 0.8307
# Epoch 131/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1933 - accuracy: 0.9382 - val_loss: 0.5412 - val_accuracy: 0.8353
# Epoch 132/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1876 - accuracy: 0.9357 - val_loss: 0.5786 - val_accuracy: 0.8252
# Epoch 133/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1951 - accuracy: 0.9357 - val_loss: 0.6137 - val_accuracy: 0.8202
# Epoch 134/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1750 - accuracy: 0.9444 - val_loss: 0.6264 - val_accuracy: 0.8227
# Epoch 135/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1780 - accuracy: 0.9419 - val_loss: 0.6073 - val_accuracy: 0.8232
# Epoch 136/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1690 - accuracy: 0.9439 - val_loss: 0.6319 - val_accuracy: 0.8322
# Epoch 137/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1798 - accuracy: 0.9422 - val_loss: 0.5496 - val_accuracy: 0.8393
# Epoch 138/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1829 - accuracy: 0.9376 - val_loss: 0.6534 - val_accuracy: 0.8112
# Epoch 139/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1774 - accuracy: 0.9419 - val_loss: 0.6127 - val_accuracy: 0.8272
# Epoch 140/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1781 - accuracy: 0.9416 - val_loss: 0.5863 - val_accuracy: 0.8252
# Epoch 141/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1655 - accuracy: 0.9491 - val_loss: 0.6497 - val_accuracy: 0.8107
# Epoch 142/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1668 - accuracy: 0.9476 - val_loss: 0.5833 - val_accuracy: 0.8307
# Epoch 143/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1778 - accuracy: 0.9429 - val_loss: 0.6721 - val_accuracy: 0.8142
# Epoch 144/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1714 - accuracy: 0.9442 - val_loss: 0.5651 - val_accuracy: 0.8383
# Epoch 145/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1642 - accuracy: 0.9479 - val_loss: 0.5998 - val_accuracy: 0.8242
# Epoch 146/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1677 - accuracy: 0.9459 - val_loss: 0.5578 - val_accuracy: 0.8413
# Epoch 147/250
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1677 - accuracy: 0.9417 - val_loss: 0.6483 - val_accuracy: 0.8177
# Epoch 148/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1660 - accuracy: 0.9461 - val_loss: 0.5735 - val_accuracy: 0.8398
# Epoch 149/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1608 - accuracy: 0.9476 - val_loss: 0.5885 - val_accuracy: 0.8358
# Epoch 150/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1559 - accuracy: 0.9486 - val_loss: 0.6251 - val_accuracy: 0.8242
# Epoch 151/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1561 - accuracy: 0.9514 - val_loss: 0.6434 - val_accuracy: 0.8217
# Epoch 152/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1620 - accuracy: 0.9471 - val_loss: 0.5673 - val_accuracy: 0.8423
# Epoch 153/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1478 - accuracy: 0.9501 - val_loss: 0.5966 - val_accuracy: 0.8307
# Epoch 154/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1641 - accuracy: 0.9436 - val_loss: 0.6025 - val_accuracy: 0.8302
# Epoch 155/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1633 - accuracy: 0.9474 - val_loss: 0.5900 - val_accuracy: 0.8358
# Epoch 156/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1508 - accuracy: 0.9524 - val_loss: 0.6643 - val_accuracy: 0.8087
# Epoch 157/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1584 - accuracy: 0.9508 - val_loss: 0.5987 - val_accuracy: 0.8368
# Epoch 158/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1405 - accuracy: 0.9574 - val_loss: 0.5846 - val_accuracy: 0.8408
# Epoch 159/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1527 - accuracy: 0.9464 - val_loss: 0.5868 - val_accuracy: 0.8292
# Epoch 160/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1413 - accuracy: 0.9523 - val_loss: 0.6417 - val_accuracy: 0.8122
# Epoch 161/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1457 - accuracy: 0.9509 - val_loss: 0.6230 - val_accuracy: 0.8287
# Epoch 162/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1479 - accuracy: 0.9519 - val_loss: 0.6334 - val_accuracy: 0.8282
# Epoch 163/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1429 - accuracy: 0.9534 - val_loss: 0.6646 - val_accuracy: 0.8197
# Epoch 164/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1535 - accuracy: 0.9501 - val_loss: 0.6149 - val_accuracy: 0.8287
# Epoch 165/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1395 - accuracy: 0.9543 - val_loss: 0.5861 - val_accuracy: 0.8353
# Epoch 166/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1357 - accuracy: 0.9574 - val_loss: 0.6789 - val_accuracy: 0.8132
# Epoch 167/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1474 - accuracy: 0.9511 - val_loss: 0.5566 - val_accuracy: 0.8403
# Epoch 168/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1437 - accuracy: 0.9523 - val_loss: 0.6365 - val_accuracy: 0.8272
# Epoch 169/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1445 - accuracy: 0.9523 - val_loss: 0.5939 - val_accuracy: 0.8292
# Epoch 170/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1384 - accuracy: 0.9543 - val_loss: 0.6180 - val_accuracy: 0.8207
# Epoch 171/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1342 - accuracy: 0.9541 - val_loss: 0.6040 - val_accuracy: 0.8312
# Epoch 172/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1365 - accuracy: 0.9553 - val_loss: 0.6043 - val_accuracy: 0.8378
# Epoch 173/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1222 - accuracy: 0.9616 - val_loss: 0.5634 - val_accuracy: 0.8463
# Epoch 174/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1287 - accuracy: 0.9576 - val_loss: 0.6412 - val_accuracy: 0.8267
# Epoch 175/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1256 - accuracy: 0.9564 - val_loss: 0.6466 - val_accuracy: 0.8247
# Epoch 176/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1226 - accuracy: 0.9609 - val_loss: 0.5629 - val_accuracy: 0.8463
# Epoch 177/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1260 - accuracy: 0.9613 - val_loss: 0.6137 - val_accuracy: 0.8317
# Epoch 178/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1271 - accuracy: 0.9586 - val_loss: 0.5823 - val_accuracy: 0.8393
# Epoch 179/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1253 - accuracy: 0.9586 - val_loss: 0.5936 - val_accuracy: 0.8317
# Epoch 180/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1271 - accuracy: 0.9589 - val_loss: 0.5781 - val_accuracy: 0.8428
# Epoch 181/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1349 - accuracy: 0.9564 - val_loss: 0.5827 - val_accuracy: 0.8438
# Epoch 182/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1210 - accuracy: 0.9603 - val_loss: 0.5681 - val_accuracy: 0.8388
# Epoch 183/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1221 - accuracy: 0.9604 - val_loss: 0.6231 - val_accuracy: 0.8302
# Epoch 184/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1326 - accuracy: 0.9564 - val_loss: 0.5932 - val_accuracy: 0.8388
# Epoch 185/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1287 - accuracy: 0.9593 - val_loss: 0.5672 - val_accuracy: 0.8463
# Epoch 186/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1199 - accuracy: 0.9634 - val_loss: 0.6076 - val_accuracy: 0.8287
# Epoch 187/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1290 - accuracy: 0.9581 - val_loss: 0.6161 - val_accuracy: 0.8307
# Epoch 188/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1274 - accuracy: 0.9579 - val_loss: 0.6019 - val_accuracy: 0.8312
# Epoch 189/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1159 - accuracy: 0.9636 - val_loss: 0.5851 - val_accuracy: 0.8368
# Epoch 190/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1112 - accuracy: 0.9639 - val_loss: 0.6304 - val_accuracy: 0.8217
# Epoch 191/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1208 - accuracy: 0.9624 - val_loss: 0.6213 - val_accuracy: 0.8307
# Epoch 192/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1200 - accuracy: 0.9598 - val_loss: 0.5553 - val_accuracy: 0.8453
# Epoch 193/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1173 - accuracy: 0.9634 - val_loss: 0.5956 - val_accuracy: 0.8408
# Epoch 194/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1081 - accuracy: 0.9649 - val_loss: 0.6058 - val_accuracy: 0.8307
# Epoch 195/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1112 - accuracy: 0.9649 - val_loss: 0.5441 - val_accuracy: 0.8478
# Epoch 196/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1135 - accuracy: 0.9638 - val_loss: 0.5778 - val_accuracy: 0.8353
# Epoch 197/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1128 - accuracy: 0.9626 - val_loss: 0.6344 - val_accuracy: 0.8307
# Epoch 198/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1224 - accuracy: 0.9586 - val_loss: 0.5959 - val_accuracy: 0.8378
# Epoch 199/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1188 - accuracy: 0.9606 - val_loss: 0.6010 - val_accuracy: 0.8353
# Epoch 200/250
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1106 - accuracy: 0.9619 - val_loss: 0.6259 - val_accuracy: 0.8322
# Epoch 201/250
# 188/188 [==============================] - 2s 11ms/step - loss: 0.1103 - accuracy: 0.9644 - val_loss: 0.6016 - val_accuracy: 0.8348
# Epoch 202/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1078 - accuracy: 0.9639 - val_loss: 0.5827 - val_accuracy: 0.8428
# Epoch 203/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1079 - accuracy: 0.9628 - val_loss: 0.5522 - val_accuracy: 0.8453
# Epoch 204/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1062 - accuracy: 0.9666 - val_loss: 0.5923 - val_accuracy: 0.8348
# Epoch 205/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1069 - accuracy: 0.9641 - val_loss: 0.6216 - val_accuracy: 0.8307
# Epoch 206/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1162 - accuracy: 0.9614 - val_loss: 0.5594 - val_accuracy: 0.8498
# Epoch 207/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1134 - accuracy: 0.9616 - val_loss: 0.5858 - val_accuracy: 0.8428
# Epoch 208/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1036 - accuracy: 0.9668 - val_loss: 0.5632 - val_accuracy: 0.8478
# Epoch 209/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0966 - accuracy: 0.9718 - val_loss: 0.5831 - val_accuracy: 0.8448
# Epoch 210/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1035 - accuracy: 0.9661 - val_loss: 0.6478 - val_accuracy: 0.8277
# Epoch 211/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1041 - accuracy: 0.9670 - val_loss: 0.5470 - val_accuracy: 0.8493
# Epoch 212/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1063 - accuracy: 0.9643 - val_loss: 0.5689 - val_accuracy: 0.8498
# Epoch 213/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1006 - accuracy: 0.9696 - val_loss: 0.5438 - val_accuracy: 0.8458
# Epoch 214/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1154 - accuracy: 0.9609 - val_loss: 0.6188 - val_accuracy: 0.8317
# Epoch 215/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0908 - accuracy: 0.9723 - val_loss: 0.6721 - val_accuracy: 0.8292
# Epoch 216/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0905 - accuracy: 0.9731 - val_loss: 0.6146 - val_accuracy: 0.8338
# Epoch 217/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1009 - accuracy: 0.9681 - val_loss: 0.5216 - val_accuracy: 0.8578
# Epoch 218/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0917 - accuracy: 0.9691 - val_loss: 0.5820 - val_accuracy: 0.8413
# Epoch 219/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1041 - accuracy: 0.9671 - val_loss: 0.5953 - val_accuracy: 0.8423
# Epoch 220/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0903 - accuracy: 0.9715 - val_loss: 0.6235 - val_accuracy: 0.8398
# Epoch 221/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0916 - accuracy: 0.9698 - val_loss: 0.6171 - val_accuracy: 0.8418
# Epoch 222/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0999 - accuracy: 0.9696 - val_loss: 0.5993 - val_accuracy: 0.8398
# Epoch 223/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0859 - accuracy: 0.9725 - val_loss: 0.5626 - val_accuracy: 0.8513
# Epoch 224/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0884 - accuracy: 0.9736 - val_loss: 0.6189 - val_accuracy: 0.8292
# Epoch 225/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0894 - accuracy: 0.9696 - val_loss: 0.5680 - val_accuracy: 0.8418
# Epoch 226/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0965 - accuracy: 0.9685 - val_loss: 0.5673 - val_accuracy: 0.8488
# Epoch 227/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1032 - accuracy: 0.9663 - val_loss: 0.5495 - val_accuracy: 0.8483
# Epoch 228/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0893 - accuracy: 0.9721 - val_loss: 0.5784 - val_accuracy: 0.8428
# Epoch 229/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0868 - accuracy: 0.9725 - val_loss: 0.5555 - val_accuracy: 0.8448
# Epoch 230/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0866 - accuracy: 0.9708 - val_loss: 0.6229 - val_accuracy: 0.8322
# Epoch 231/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0881 - accuracy: 0.9701 - val_loss: 0.5814 - val_accuracy: 0.8423
# Epoch 232/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0966 - accuracy: 0.9693 - val_loss: 0.5987 - val_accuracy: 0.8413
# Epoch 233/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0881 - accuracy: 0.9701 - val_loss: 0.5836 - val_accuracy: 0.8498
# Epoch 234/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0961 - accuracy: 0.9685 - val_loss: 0.5366 - val_accuracy: 0.8563
# Epoch 235/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0973 - accuracy: 0.9680 - val_loss: 0.5504 - val_accuracy: 0.8503
# Epoch 236/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0949 - accuracy: 0.9696 - val_loss: 0.5435 - val_accuracy: 0.8523
# Epoch 237/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0923 - accuracy: 0.9703 - val_loss: 0.5395 - val_accuracy: 0.8538
# Epoch 238/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0916 - accuracy: 0.9716 - val_loss: 0.5461 - val_accuracy: 0.8503
# Epoch 239/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0790 - accuracy: 0.9751 - val_loss: 0.5646 - val_accuracy: 0.8538
# Epoch 240/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0894 - accuracy: 0.9723 - val_loss: 0.5555 - val_accuracy: 0.8513
# Epoch 241/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0838 - accuracy: 0.9731 - val_loss: 0.5669 - val_accuracy: 0.8463
# Epoch 242/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0872 - accuracy: 0.9713 - val_loss: 0.5661 - val_accuracy: 0.8438
# Epoch 243/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0828 - accuracy: 0.9753 - val_loss: 0.5636 - val_accuracy: 0.8478
# Epoch 244/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0795 - accuracy: 0.9760 - val_loss: 0.5530 - val_accuracy: 0.8513
# Epoch 245/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0809 - accuracy: 0.9738 - val_loss: 0.5574 - val_accuracy: 0.8563
# Epoch 246/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0804 - accuracy: 0.9735 - val_loss: 0.5887 - val_accuracy: 0.8478
# Epoch 247/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0831 - accuracy: 0.9743 - val_loss: 0.6018 - val_accuracy: 0.8373
# Epoch 248/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0933 - accuracy: 0.9688 - val_loss: 0.5738 - val_accuracy: 0.8488
# Epoch 249/250
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0797 - accuracy: 0.9760 - val_loss: 0.6091 - val_accuracy: 0.8468
# Epoch 250/250
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0780 - accuracy: 0.9746 - val_loss: 0.5926 - val_accuracy: 0.8498
# Test Accuracy: 0.8573573573573574
