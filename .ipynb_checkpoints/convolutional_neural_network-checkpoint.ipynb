# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATA_PATH = 'data.json' # path of the file which has the processed data stored in JSON format

def load_data(data_path):
    '''
    function to load data from the JSON file
    param: data_path -> string -> the path of the JSON file which will be used to load data
    return: X -> ndarray -> the extracted input features from the loaded file
            Y -> ndarray -> the expected output for the corresponding inputs in X
    '''
    
    with open(data_path, 'r') as fp:
        data = json.load(fp)
    
    # converting list to ndarrays
    X = np.array(data['mfcc'])
    Y = np.array(data['labels'])
    print('Data Loaded Successfully!')
    
    return X, Y

X, Y = load_data(DATA_PATH) # loading data to X and Y

def plot_history(history):
    # function to plot the history of the training of the model
    
    fig, axs = plt.subplots(2)
    
    # plotting accuracy history of training and validation datasets
    axs[0].plot(history.history["accuracy"], label = 'train-accuracy')
    axs[0].plot(history.history["val_accuracy"], label = 'validation-accuracy')
    axs[0].set_ylabel('accuracy')
    axs[0].set_xlabel('epochs')
    axs[0].legend(loc = 'lower right')
    axs[0].set_title('Accuracy Evaluation')
    
    # plotting error history of training and validation datasets
    axs[1].plot(history.history["loss"], label = 'training-loss')
    axs[1].plot(history.history["val_loss"], label = 'validation-loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].legend('upper right')
    axs[1].set_title('Loss Evaluation')
    
    plt.show()
    
def prepare_dataset(validation_size, test_size):
    # function to split the dataset into traning, validation and test sets
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_size)
    X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = validation_size)
    return X_train, X_val, X_test, Y_train, Y_val, Y_test

def build_model(input_shape):
    # building a Convolutional Neural Network
    model = keras.Sequential()
    
    #adding convolutional and pooling layers to the model
    model.add(keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = input_shape)) # convoluition layer
    model.add(keras.layers.MaxPooling2D((3, 3), strides = (2, 2), padding = 'same')) # pooling layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation = 'relu')) # convolution layer
    model.add(keras.layers.MaxPooling2D((3, 3), strides = (2, 2), padding = 'same')) # pooling layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation = 'relu')) # convolution layer
    model.add(keras.layers.MaxPooling2D((2, 2), strides = (2, 2), padding = 'same')) # pooling layer
    model.add(keras.layers.BatchNormalization())
    
    # flattening thte CNN grid
    model.add(keras.layers.Flatten())
    
    # dense neural network layer
    model.add(keras.layers.Dense(64, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3)) # dropout to avoid overfitting
    # final softmax layer 
    model.add(keras.layers.Dense(10, activation = 'softmax'))

    return model
# Out:
# Data Loaded Successfully!

# %%
def predict(model, X, Y):
    # function to predict the output using the trained model
    X = X[np.newaxis, ...]
    
    prediction = model.predict(X)
    
    predicted_index = np.argmax(prediction, axis = 1)
    
    print(f'Target: {Y}, predicted: {predicted_index}')
    
    
if(__name__ == '__main__'):
    X_train, X_val, X_test, Y_train, Y_val, Y_test = prepare_dataset(0.25, 0.2)
    
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)
    
    optimizer = keras.optimizers.Adam(learning_rate = 0.00005)
    
    model.compile(optimizer = optimizer,
                 loss = 'sparse_categorical_crossentropy',
                 metrics = ['accuracy'])
    
    model.summary()
    
    history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), batch_size = 32, epochs = 50)
    
    plot_history(history)
    
    test_loss, test_acc = model.evaluate(X_test, Y_test, verbose = 2)
    
    print(f'Test Accuracy: {test_acc}')
    
    X_to_predict = X_test[300]
    Y_to_predict = Y_test[300]
    
    predict(model, X_to_predict, Y_to_predict)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 128, 11, 32)       320
#
#  max_pooling2d_9 (MaxPooling  (None, 64, 6, 32)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 62, 4, 32)         9248
#
#  max_pooling2d_10 (MaxPoolin  (None, 31, 2, 32)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 30, 1, 32)         4128
#
#  max_pooling2d_11 (MaxPoolin  (None, 15, 1, 32)        0
#  g2D)
#
#  batch_normalization_3 (Batc  (None, 15, 1, 32)        128
#  hNormalization)
#
#  flatten_3 (Flatten)         (None, 480)               0
#
#  dense_6 (Dense)             (None, 64)                30784
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 45,258
# Trainable params: 45,194
# Non-trainable params: 64
# _________________________________________________________________
# Epoch 1/50
# 188/188 [==============================] - 10s 43ms/step - loss: 2.6632 - accuracy: 0.1544 - val_loss: 2.0625 - val_accuracy: 0.2669
# Epoch 2/50
# 188/188 [==============================] - 8s 43ms/step - loss: 2.0169 - accuracy: 0.3001 - val_loss: 1.7758 - val_accuracy: 0.3570
# Epoch 3/50
# 188/188 [==============================] - 7s 40ms/step - loss: 1.8151 - accuracy: 0.3567 - val_loss: 1.6305 - val_accuracy: 0.4006
# Epoch 4/50
# 188/188 [==============================] - 7s 38ms/step - loss: 1.7054 - accuracy: 0.3928 - val_loss: 1.5417 - val_accuracy: 0.4347
# Epoch 5/50
# 188/188 [==============================] - 7s 39ms/step - loss: 1.6365 - accuracy: 0.4128 - val_loss: 1.4951 - val_accuracy: 0.4437
# Epoch 6/50
# 188/188 [==============================] - 7s 38ms/step - loss: 1.5819 - accuracy: 0.4347 - val_loss: 1.4616 - val_accuracy: 0.4767
# Epoch 7/50
# 188/188 [==============================] - 7s 37ms/step - loss: 1.5264 - accuracy: 0.4517 - val_loss: 1.3899 - val_accuracy: 0.4922
# Epoch 8/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.4908 - accuracy: 0.4574 - val_loss: 1.3622 - val_accuracy: 0.4952
# Epoch 9/50
# 188/188 [==============================] - 7s 37ms/step - loss: 1.4443 - accuracy: 0.4884 - val_loss: 1.3428 - val_accuracy: 0.4947
# Epoch 10/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.4304 - accuracy: 0.4839 - val_loss: 1.3063 - val_accuracy: 0.5228
# Epoch 11/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.3949 - accuracy: 0.5003 - val_loss: 1.2916 - val_accuracy: 0.5243
# Epoch 12/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.3550 - accuracy: 0.5104 - val_loss: 1.2580 - val_accuracy: 0.5283
# Epoch 13/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.3201 - accuracy: 0.5183 - val_loss: 1.2261 - val_accuracy: 0.5453
# Epoch 14/50
# 188/188 [==============================] - 10s 52ms/step - loss: 1.3246 - accuracy: 0.5265 - val_loss: 1.2533 - val_accuracy: 0.5323
# Epoch 15/50
# 188/188 [==============================] - 38s 202ms/step - loss: 1.3016 - accuracy: 0.5311 - val_loss: 1.1980 - val_accuracy: 0.5669
# Epoch 16/50
# 188/188 [==============================] - 8s 42ms/step - loss: 1.2875 - accuracy: 0.5441 - val_loss: 1.1983 - val_accuracy: 0.5759
# Epoch 17/50
# 188/188 [==============================] - 8s 40ms/step - loss: 1.2556 - accuracy: 0.5488 - val_loss: 1.1778 - val_accuracy: 0.5669
# Epoch 18/50
# 188/188 [==============================] - 8s 45ms/step - loss: 1.2424 - accuracy: 0.5520 - val_loss: 1.1931 - val_accuracy: 0.5583
# Epoch 19/50
# 188/188 [==============================] - 7s 39ms/step - loss: 1.2159 - accuracy: 0.5580 - val_loss: 1.1450 - val_accuracy: 0.5839
# Epoch 20/50
# 188/188 [==============================] - 7s 37ms/step - loss: 1.2034 - accuracy: 0.5729 - val_loss: 1.1815 - val_accuracy: 0.5779
# Epoch 21/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.1875 - accuracy: 0.5750 - val_loss: 1.1240 - val_accuracy: 0.5974
# Epoch 22/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.1810 - accuracy: 0.5737 - val_loss: 1.1110 - val_accuracy: 0.6134
# Epoch 23/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.1532 - accuracy: 0.5835 - val_loss: 1.0816 - val_accuracy: 0.6119
# Epoch 24/50
# 188/188 [==============================] - 7s 38ms/step - loss: 1.1309 - accuracy: 0.5931 - val_loss: 1.1003 - val_accuracy: 0.6124
# Epoch 25/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.1220 - accuracy: 0.6001 - val_loss: 1.1025 - val_accuracy: 0.6009
# Epoch 26/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.1125 - accuracy: 0.5992 - val_loss: 1.0787 - val_accuracy: 0.6084
# Epoch 27/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.0930 - accuracy: 0.6081 - val_loss: 1.0936 - val_accuracy: 0.6124
# Epoch 28/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.0759 - accuracy: 0.6164 - val_loss: 1.0394 - val_accuracy: 0.6319
# Epoch 29/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.0624 - accuracy: 0.6224 - val_loss: 1.0889 - val_accuracy: 0.6034
# Epoch 30/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.0351 - accuracy: 0.6316 - val_loss: 1.0149 - val_accuracy: 0.6430
# Epoch 31/50
# 188/188 [==============================] - 7s 35ms/step - loss: 1.0320 - accuracy: 0.6341 - val_loss: 1.0288 - val_accuracy: 0.6309
# Epoch 32/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.0250 - accuracy: 0.6418 - val_loss: 1.1243 - val_accuracy: 0.5964
# Epoch 33/50
# 188/188 [==============================] - 7s 36ms/step - loss: 1.0083 - accuracy: 0.6433 - val_loss: 1.0339 - val_accuracy: 0.6400
# Epoch 34/50
# 188/188 [==============================] - 7s 35ms/step - loss: 0.9963 - accuracy: 0.6506 - val_loss: 0.9900 - val_accuracy: 0.6550
# Epoch 35/50
# 188/188 [==============================] - 7s 35ms/step - loss: 0.9811 - accuracy: 0.6525 - val_loss: 1.0201 - val_accuracy: 0.6299
# Epoch 36/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.9758 - accuracy: 0.6557 - val_loss: 0.9654 - val_accuracy: 0.6605
# Epoch 37/50
# 188/188 [==============================] - 7s 35ms/step - loss: 0.9651 - accuracy: 0.6587 - val_loss: 0.9804 - val_accuracy: 0.6485
# Epoch 38/50
# 188/188 [==============================] - 7s 35ms/step - loss: 0.9567 - accuracy: 0.6600 - val_loss: 0.9973 - val_accuracy: 0.6485
# Epoch 39/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.9346 - accuracy: 0.6707 - val_loss: 0.9846 - val_accuracy: 0.6450
# Epoch 40/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.9378 - accuracy: 0.6700 - val_loss: 0.9529 - val_accuracy: 0.6690
# Epoch 41/50
# 188/188 [==============================] - 7s 37ms/step - loss: 0.9149 - accuracy: 0.6799 - val_loss: 0.9302 - val_accuracy: 0.6685
# Epoch 42/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.9089 - accuracy: 0.6862 - val_loss: 0.9327 - val_accuracy: 0.6685
# Epoch 43/50
# 188/188 [==============================] - 7s 35ms/step - loss: 0.9068 - accuracy: 0.6809 - val_loss: 0.9242 - val_accuracy: 0.6805
# Epoch 44/50
# 188/188 [==============================] - 7s 35ms/step - loss: 0.8949 - accuracy: 0.6867 - val_loss: 0.9190 - val_accuracy: 0.6720
# Epoch 45/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.8777 - accuracy: 0.6894 - val_loss: 0.9612 - val_accuracy: 0.6745
# Epoch 46/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.8748 - accuracy: 0.6920 - val_loss: 1.0212 - val_accuracy: 0.6500
# Epoch 47/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.8610 - accuracy: 0.7014 - val_loss: 0.9785 - val_accuracy: 0.6450
# Epoch 48/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.8613 - accuracy: 0.6974 - val_loss: 0.9360 - val_accuracy: 0.6820
# Epoch 49/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.8468 - accuracy: 0.7021 - val_loss: 0.9120 - val_accuracy: 0.6725
# Epoch 50/50
# 188/188 [==============================] - 7s 36ms/step - loss: 0.8440 - accuracy: 0.7021 - val_loss: 0.9592 - val_accuracy: 0.6750
# 63/63 - 0s - loss: 0.9536 - accuracy: 0.6747 - 478ms/epoch - 8ms/step
# Test Accuracy: 0.6746746897697449
# 1/1 [==============================] - 0s 119ms/step
# Target: 3, predicted: [3]
